# %% [markdown]
# ## How Our Dating Pattern Has Changed

# %% [markdown]
# Data Source: https://data.stanford.edu/hcmst2017
#
# Dictionary: https://www.visualcapitalist.com/online-dating-big-business/

# %%
import pandas as pd
from datetime import datetime

data = pd.io.stata.read_stata('HCMST 2017 fresh sample for public sharing draft v1.1.dta')
data.to_csv('my_stata_file.csv')

# %%
df = pd.read_csv('my_stata_file.csv', low_memory=False)
df.head()
# Out:
#    Unnamed: 0  CaseID  CASEID_NEW      qflag  weight1  weight1_freqwt  \
# 0           0       2     2014039  Qualified      NaN             NaN
# 1           1       3     2019003  Qualified   0.9078         71115.0
# 2           2       5     2145527  Qualified   0.7205         56442.0
# 3           3       6     2648857  Qualified   1.2597         98682.0
# 4           4       7     2623465  Qualified   0.8686         68044.0
#
#    weight2  weight1a  weight1a_freqwt  weight_combo      ...       \
# 0   0.8945       NaN              NaN      0.277188      ...
# 1      NaN    0.9026          70707.0      1.020621      ...
# 2      NaN    0.7164          56121.0      0.810074      ...
# 3   1.3507    1.2524          98110.0      0.418556      ...
# 4      NaN    0.8636          67652.0      0.976522      ...
#
#    hcm2017q24_met_through_family  hcm2017q24_met_through_friend  \
# 0                             no                             no
# 1                             no                             no
# 2                             no                             no
# 3                             no                             no
# 4                             no                             no
#
#   hcm2017q24_met_through_as_nghbrs hcm2017q24_met_as_through_cowork  \
# 0                               no                               no
# 1                               no                              yes
# 2                               no                               no
# 3                               no                               no
# 4                              yes                               no
#
#   w6_subject_race interracial_5cat partner_mother_yrsed subject_mother_yrsed  \
# 0           White               no                 12.0                 14.0
# 1           White               no                 12.0                 16.0
# 2           White               no                  9.0                  7.5
# 3           White               no                 16.0                 12.0
# 4           White               no                 14.0                 17.0
#
#    partner_yrsed subject_yrsed
# 0           12.0          14.0
# 1           17.0          17.0
# 2           14.0          17.0
# 3           12.0          12.0
# 4           16.0          16.0
#
# [5 rows x 286 columns]

# %%
first_met = df.loc[(df['Q21A_Year'] != 'Refused') & df.loc[(df['Q21A_Year'] != 'NaN')]]
first_met["Q21A_Year"] = pd.to_numeric(first_met["Q21A_Year"])
# bins = pd.cut(df['Q21A_Year'], [1960, 1969, 1970, 1979, 1980, 1989, 1990, 1999, 2000, 2009, 2010, 2019])
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:3772: RuntimeWarning: '<' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects
#   return this.join(other, how=how, return_indexers=return_indexers)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in eval(self, func, other, errors, try_cast, mgr)
#    1354             values, values_mask, other, other_mask = self._try_coerce_args(
# -> 1355                 transf(values), other)
#    1356         except TypeError:
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in _try_coerce_args(self, values, other)
#     741                 type(other).__name__,
# --> 742                 type(self).__name__.lower().replace('Block', '')))
#     743
#
# TypeError: cannot convert ndarray to an floatblock
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1496         try:
# -> 1497             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1498         except TypeError:
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/ops.py in rand_(left, right)
#     148 def rand_(left, right):
# --> 149     return operator.and_(right, left)
#     150
#
# TypeError: unsupported operand type(s) for &: 'bool' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-4094230d504a> in <module>()
# ----> 1 first_met = df.loc[(df['Q21A_Year'] != 'Refused') & df.loc[(df['Q21A_Year'] != 'NaN')]]
#       2 first_met["Q21A_Year"] = pd.to_numeric(first_met["Q21A_Year"])
#       3 # bins = pd.cut(df['Q21A_Year'], [1960, 1969, 1970, 1979, 1980, 1989, 1990, 1999, 2000, 2009, 2010, 2019])
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/ops.py in f(self, other, axis, level, fill_value)
#    1552             return _combine_series_frame(self, other, na_op,
#    1553                                          fill_value=fill_value, axis=axis,
# -> 1554                                          level=level, try_cast=True)
#    1555         else:
#    1556             if fill_value is not None:
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/ops.py in _combine_series_frame(self, other, func, fill_value, axis, level, try_cast)
#    1425         else:
#    1426             return self._combine_match_columns(other, func, level=level,
# -> 1427                                                try_cast=try_cast)
#    1428     else:
#    1429         if not len(other):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in _combine_match_columns(self, other, func, level, try_cast)
#    4771         new_data = left._data.eval(func=func, other=right,
#    4772                                    axes=[left.columns, self.index],
# -> 4773                                    try_cast=try_cast)
#    4774         return self._constructor(new_data)
#    4775
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in eval(self, **kwargs)
#    3685
#    3686     def eval(self, **kwargs):
# -> 3687         return self.apply('eval', **kwargs)
#    3688
#    3689     def quantile(self, **kwargs):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3579
#    3580             kwargs['mgr'] = self
# -> 3581             applied = getattr(b, f)(**kwargs)
#    3582             result_blocks = _extend_blocks(applied, result_blocks)
#    3583
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in eval(self, func, other, errors, try_cast, mgr)
#    1358             return block.eval(func, orig_other,
#    1359                               errors=errors,
# -> 1360                               try_cast=try_cast, mgr=mgr)
#    1361
#    1362         # get the result, may need to transpose the other
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in eval(self, func, other, errors, try_cast, mgr)
#    1413         try:
#    1414             with np.errstate(all='ignore'):
# -> 1415                 result = get_result(other)
#    1416
#    1417         # if we have an invalid shape/broadcast error
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in get_result(other)
#    1381                 result = func(values, other)
#    1382             else:
# -> 1383                 result = func(values, other)
#    1384
#    1385             # mask if needed
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1502                 result = np.empty(x.size, dtype=dtype)
#    1503                 yrav = y.ravel()
# -> 1504                 mask = notna(xrav) & notna(yrav)
#    1505                 xrav = xrav[mask]
#    1506
#
# ValueError: operands could not be broadcast together with shapes (12460500,) (3550,)

# %%
first_met.Q21A_Year.unique
# Out:
# <bound method Series.unique of 0          NaN
# 1       1983.0
# 2       2006.0
# 3          NaN
# 4       1983.0
# 5       1981.0
# 6       1966.0
# 7       1967.0
# 8          NaN
# 9          NaN
# 10      2008.0
# 11         NaN
# 12         NaN
# 13         NaN
# 14      2007.0
# 15      2002.0
# 16      2007.0
# 17      2002.0
# 18      2004.0
# 19      1973.0
# 20      1995.0
# 21         NaN
# 22         NaN
# 23      2008.0
# 24      2000.0
# 25      1990.0
# 26         NaN
# 27      2014.0
# 28      2012.0
# 29      2010.0
#          ...
# 3480    1994.0
# 3481    2011.0
# 3482    2015.0
# 3483    2008.0
# 3484    2010.0
# 3485    2011.0
# 3486       NaN
# 3487    1996.0
# 3488    1987.0
# 3489    1998.0
# 3490    2014.0
# 3491    2000.0
# 3492       NaN
# 3493       NaN
# 3494       NaN
# 3495    2016.0
# 3496    1998.0
# 3497    2011.0
# 3498    2015.0
# 3499    2013.0
# 3500    1978.0
# 3501    2016.0
# 3502    1996.0
# 3503    1994.0
# 3504       NaN
# 3505    2015.0
# 3506    2016.0
# 3507    2012.0
# 3508    2014.0
# 3509    2015.0
# Name: Q21A_Year, Length: 3474, dtype: float64>

# %%
df['Date First Met'] = df.apply(lambda row: datetime(
                              row['Q21A_Year'], row['Q21A_Month']), axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-81df80b78739> in <module>()
#       1 df['Date First Met'] = df.apply(lambda row: datetime(
# ----> 2                               row['Q21A_Year'], row['Q21A_Month']), axis=1)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-15-81df80b78739> in <lambda>(row)
#       1 df['Date First Met'] = df.apply(lambda row: datetime(
# ----> 2                               row['Q21A_Year'], row['Q21A_Month']), axis=1)
#
# TypeError: ('integer argument expected, got float', 'occurred at index 0')
