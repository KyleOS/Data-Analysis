# %% [markdown]
# ## How Our Dating Patterns Have Changed

# %% [markdown]
# Data Source: https://data.stanford.edu/hcmst2017
#
# Dictionary: https://www.visualcapitalist.com/online-dating-big-business/

# %%
import pandas as pd
from datetime import datetime

data = pd.io.stata.read_stata('HCMST 2017 fresh sample for public sharing draft v1.1.dta')
data.to_csv('my_stata_file.csv')

# %%
df = pd.read_csv('my_stata_file.csv', low_memory=False)
df.head()
# Out:
#    Unnamed: 0  CaseID  CASEID_NEW      qflag  weight1  weight1_freqwt  \
# 0           0       2     2014039  Qualified      NaN             NaN
# 1           1       3     2019003  Qualified   0.9078         71115.0
# 2           2       5     2145527  Qualified   0.7205         56442.0
# 3           3       6     2648857  Qualified   1.2597         98682.0
# 4           4       7     2623465  Qualified   0.8686         68044.0
#
#    weight2  weight1a  weight1a_freqwt  weight_combo  ...  \
# 0   0.8945       NaN              NaN      0.277188  ...
# 1      NaN    0.9026          70707.0      1.020621  ...
# 2      NaN    0.7164          56121.0      0.810074  ...
# 3   1.3507    1.2524          98110.0      0.418556  ...
# 4      NaN    0.8636          67652.0      0.976522  ...
#
#    hcm2017q24_met_through_family  hcm2017q24_met_through_friend  \
# 0                             no                             no
# 1                             no                             no
# ...

# %%
first_met = df.loc[(df['Q21A_Year'] != 'Refused') & df.loc[(df['Q21A_Year'] != 'NaN')]]
# first_met["Q21A_Year"] = pd.to_numeric(first_met["Q21A_Year"])
# bins = pd.cut(df['Q21A_Year'], [1960, 1969, 1970, 1979, 1980, 1989, 1990, 1999, 2000, 2009, 2010, 2019])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1788         try:
# -> 1789             result = op(x, y)
#    1790         except TypeError:
#
# /usr/local/lib/python3.7/site-packages/pandas/core/ops.py in rand_(left, right)
#     186 def rand_(left, right):
# --> 187     return operator.and_(right, left)
#     188
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1803                 try:
# ...

# %%
first_met.Q21A_Year.unique
# Out:
# <bound method Series.unique of 0          NaN
# 1       1983.0
# 2       2006.0
# 3          NaN
# 4       1983.0
# 5       1981.0
# 6       1966.0
# 7       1967.0
# 8          NaN
# 9          NaN
# 10      2008.0
# 11         NaN
# 12         NaN
# 13         NaN
# 14      2007.0
# 15      2002.0
# 16      2007.0
# 17      2002.0
# 18      2004.0
# 19      1973.0
# 20      1995.0
# 21         NaN
# 22         NaN
# 23      2008.0
# 24      2000.0
# 25      1990.0
# 26         NaN
# 27      2014.0
# 28      2012.0
# 29      2010.0
#          ...
# 3480    1994.0
# 3481    2011.0
# 3482    2015.0
# 3483    2008.0
# 3484    2010.0
# 3485    2011.0
# 3486       NaN
# 3487    1996.0
# 3488    1987.0
# 3489    1998.0
# 3490    2014.0
# 3491    2000.0
# 3492       NaN
# 3493       NaN
# 3494       NaN
# 3495    2016.0
# 3496    1998.0
# 3497    2011.0
# 3498    2015.0
# 3499    2013.0
# 3500    1978.0
# 3501    2016.0
# 3502    1996.0
# 3503    1994.0
# 3504       NaN
# 3505    2015.0
# ...

# %%
df['Date First Met'] = df.apply(lambda row: datetime(
                              row['Q21A_Year'], row['Q21A_Month']), axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-81df80b78739> in <module>
#       1 df['Date First Met'] = df.apply(lambda row: datetime(
# ----> 2                               row['Q21A_Year'], row['Q21A_Month']), axis=1)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# ...
