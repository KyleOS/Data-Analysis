# %% [markdown]
# https://unctad.org/en/Pages/DIAE/FDI%20Statistics/FDI-Statistics-Bilateral.aspx
#
#
#     https://unctad.org/Sections/dite_fdistat/docs/webdiaeia2014d3_CHN.pdf

# %%
import pandas as pd
import math
import numpy as np

import plotly.plotly as py
import plotly.graph_objs as go
import plotly
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
cf.set_config_file(offline=True)

import plotly_express as px
import country_converter as coco
import pycountry
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
df = pd.read_csv('WITS-Partner-Timeseries (1).csv',encoding = "ISO-8859-1").drop(['Reporter Name', 'Trade Flow', 'Indicator'],axis=1).set_index('Partner Name')
df.head().T.iplot(theme='white')

# %%
df1 = df[['2017']]
df1 = df1.reset_index()
df1.head()
# Out:
#   Partner Name     2017
# 0  Afghanistan  30.3017
# 1      Albania  39.8276
# 2      Algeria  56.6115
# 3      Andorra   4.3547
# 4       Angola  50.0567

# %%
df2 = df[['2000']]
df2 = df2.reset_index()
df2.head()
# Out:
#   Partner Name     2000
# 0  Afghanistan   3.3972
# 1      Albania   8.2118
# 2      Algeria  20.9254
# 3      Andorra   0.3543
# 4       Angola   7.8366

# %%
plotmap = [ dict(
        type = 'choropleth',
        locations = df1['Code'],
        locationmode = 'ISO-3',
        z = df1['2017'],
        colorscale = 'YlOrRd',
        reversescale = True,
        marker = dict(
            line = dict (
                color = 'rgb(180,180,180)',
                width = 0.5
            ) ),
        colorbar =go.choropleth.ColorBar(
            title = 'Percent of Imports',
            len=0.5
        ),
      ) ]

layout = dict(
    margin={"t": 0, "b": 0, "l": 0, "r": 0},
    geo = dict(
        showframe = False,
        showcoastlines = False,
        projection = dict(
            type = 'natural earth'
        )
    ),
     height=700,
    width=900
)

fig = dict( data=plotmap, layout=layout )
iplot(fig)
# Out:
# <div>
#
#
#             <div id="0e20e098-61ec-4d30-a7ea-c467cc365fc5" class="plotly-graph-div" style="height:700px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://type-here.com';
#
#                 if (document.getElementById("0e20e098-61ec-4d30-a7ea-c467cc365fc5")) {
#                     Plotly.newPlot(
#                         '0e20e098-61ec-4d30-a7ea-c467cc365fc5',
# ...

# %%
def get_country_code(name):
    for co in list(pycountry.countries):
        if name in co.name:
            return co.alpha_3
    return None


# for name in df1['Partner Name']:
#     print(name, get_country_code(name))

df1['Code'] = df1['Partner Name'].apply(get_country_code)
df2['Code'] = df2['Partner Name'].apply(get_country_code)
df1 = df1.dropna()
df2 = df2.dropna()

# %%
def map_plot(x):
    plotmap = [ dict(
            type = 'choropleth',
            locations = df1['Code'],
            locationmode = 'ISO-3',
            z = x,
            colorscale = 'YlOrRd',
            reversescale = True,
            marker = dict(
                line = dict (
                    color = 'rgb(180,180,180)',
                    width = 0.5
                ) ),
            colorbar =go.choropleth.ColorBar(
                title = 'Percent of Imports',
                len=0.5
            ),
          ) ]

    layout = dict(
        margin={"t": 0, "b": 0, "l": 0, "r": 0},
        geo = dict(
            showframe = False,
            showcoastlines = False,
            projection = dict(
                type = 'natural earth'
            )
        ),
         height=700,
        width=900
    )

    fig = dict( data=plotmap, layout=layout )
    iplot(fig)
    
map_plot(df2['2000']) 
map_plot(df1['2017'])
# Out:
# <div>
#
#
#             <div id="91fdbc7f-6208-44af-814c-051339f5b6f0" class="plotly-graph-div" style="height:700px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://type-here.com';
#
#                 if (document.getElementById("91fdbc7f-6208-44af-814c-051339f5b6f0")) {
#                     Plotly.newPlot(
#                         '91fdbc7f-6208-44af-814c-051339f5b6f0',
# ...

# %%
df = pd.read_csv('WITS-Partner-Timeseries (1).csv',encoding = "ISO-8859-1").drop(['Reporter Name', 'Trade Flow', 'Indicator'],axis=1).set_index('Partner Name')
def get_country_code(name):
    for co in list(pycountry.countries):
        if name in co.name:
            return co.alpha_3
    return None


# for name in df1['Partner Name']:
#     print(name, get_country_code(name))

df = df.reset_index()

df['Code'] = df['Partner Name'].apply(get_country_code)
df = df.dropna()
df.set_index('Code').T

df = df.melt(id_vars=["Partner Name", "Code"], 
        var_name="Year", 
        value_name="Value")

df = df.sort_values(['Partner Name', 'Code'], ascending=[True, True])
