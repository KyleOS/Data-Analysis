# %%
import pandas as pd

# %%
df = pd.read_csv('independence.csv',encoding = "ISO-8859-1",names=["Country", "Date of Indpendence", "Ruling Nation"])
df
# Out:
#                                 Country  \
# 0                               Algeria
# 1                                Angola
# 2                                 Benin
# 3                              Botswana
# 4                          Burkina Faso
# 5                               Burundi
# 6                            Cape Verde
# 7                              Cameroon
# 8              Central African Republic
# 9                                  Chad
# 10                              Comoros
# 11    Congo, Democratic Republic of the
# 12               Congo, Republic of the
# 13                          Ivory Coast
# 14                       August 7, 1960
# 15                             Djibouti
# 16                                Egypt
# 17                    Equatorial Guinea
# 18                              Eritrea
# 19                 Eswatini (Swaziland)
# 20                             Ethiopia
# 21                                Gabon
# ...

# %%
# df.loc[df['Ruling Nation'].str.contains('France'), 'Ruling Nation'] = 'France'
# df.loc[df['Ruling Nation'].str.contains('French'), 'Ruling Nation'] = 'France'
# df.loc[df['Ruling Nation'].str.contains('Portugal'), 'Ruling Nation'] = 'Portugal'
# df.loc[df['Ruling Nation'].str.contains('Spain'), 'Ruling Nation'] = 'Spain'
# df.loc[df['Ruling Nation'].str.contains('United Kingdom'), 'Ruling Nation'] = 'United Kingdom'
# df.loc[df['Ruling Nation'].str.contains('Ottoman'), 'Ruling Nation'] = 'Ottoman Empire'
