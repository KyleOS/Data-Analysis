# %% [markdown]
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4462044/table/T2/?report=objectonly

# %%
import pandas as pd

# %%
df = pd.read_csv('caffeine.csv').fillna('')
df.head()
# Out:
#       Servings per day                   Item Total Caffeine (in mg)
# 0  Coffee (180 ml cup)            Drip brewed      100 mg per 180 ml
# 1                                  Percolated      120 mg per 180 ml
# 2                                     Instant      90 mg. per 180 ml
# 3                        Brewed decaffeinated        5 mg per 180 ml
# 4                       Instant decaffeinated        3 mg per 180 ml

# %%
df.set_index(['Servings per day', 'Item'], inplace=True)
df
# Out:
#                                                                             Total Caffeine (in mg)
# Servings per day         Item
# Coffee (180 ml cup)      Drip brewed                                             100 mg per 180 ml
#                          Percolated                                              120 mg per 180 ml
#                          Instant                                                 90 mg. per 180 ml
#                          Brewed decaffeinated                                      5 mg per 180 ml
#                          Instant decaffeinated                                     3 mg per 180 ml
# Tea (180 ml cup)         Green                                                    35 mg per 180 ml
#                          Black                                                    70 mg per 180 ml
#                          Canned ice tea                                       35 mg per 360 oz can
# ...
