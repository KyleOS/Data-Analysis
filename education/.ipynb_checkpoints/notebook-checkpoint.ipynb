# %% [markdown]
# ## Share of Population with no Formal Education

# %%
import pandas as pd
import plotly_express as px

# %%
df = pd.read_csv('projections-of-the-rate-of-no-education-based-on-current-global-education-trends-1970-2050.csv')
df.rename(columns = {'IIASA rates of no education projections (%)':'No Education Rate (%)'}, inplace = True)

# %%
px.choropleth(df, locations="Code", color="No Education Rate (%)", hover_name="Entity", animation_frame="Year",
             color_continuous_scale=px.colors.sequential.YlOrRd, width=1000)

# %% [markdown]
# Data Source:  International Institute for Applied Systems Analysis (IIASA) (2015), originally published by Lutz, Wolfgang, William P. Butz, and Samir (2014) World population and human capital in the twenty-first century. (https://global.oup.com/academic/product/world-population-and-human-capital-in-the-twenty-first-century-9780198703167?cc=ca&lang=en&)
