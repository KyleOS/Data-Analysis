# %% [markdown]
# Data Source: http://cgeh.nl/cgeh/#conflict
#
# Example Analysis: https://greenet09.github.io/datasophy/2018/07/07/global-violence.html

# %%
import pandas as pd

# %%
df = pd.read_csv('Conflict Catalog 18 vars.csv', encoding='ISO-8859-1').fillna('')
df.head(6)
# Out:
#   Common Name                                               Name CountryCode  \
# 0                         England (Henry IV vs Richard II), 1400
# 1                                      England-Scotland, 1400-02
# 2                                  Mongols (Timur)-Georgia, 1400
# 3                                   Mongols (Timur)-Turkey, 1400
# 4              Mongols (Timur)-Egypt, Syria (Burji Mamluks), ...
# 5              China (minority in Hebei, Shandong, Anhui, Jia...         710
#
#   NumberActors MilFatalities TotalFatalities  StartYear StartMonth StartDay  \
# 0            2                                     1400          1
# 1            2                                     1400
# 2            2                                     1400
# 3            2                                     1400          8
# 4            3                                     1400         10
# 5            2                         10000       1400
#
# ...
