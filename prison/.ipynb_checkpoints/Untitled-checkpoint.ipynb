# %%
import pandas as pd
import math
import numpy as np

import plotly.plotly as py
import plotly.graph_objs as go
import plotly
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
cf.set_config_file(offline=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
df1 = pd.read_csv('homicide.csv').set_index('Country')
df1.head()
# Out:
#              Intentional Homicide Rate
# Country
# Aruba                              NaN
# Afghanistan                        NaN
# Angola                             NaN
# Albania                       2.698926
# Andorra                            NaN

# %%
df2 = pd.read_csv('prison_pop.csv', encoding="cp1252").set_index('Country')
df2.head()
# Out:
#                           Prison Population Rate
# Country
# United States of America                     655
# El Salvador                                  618
# Thailand                                     558
# Turkmenistan                                 552
# Virgin Islands (USA)                         542

# %%
df = pd.concat([df1['Intentional Homicide Rate'], df2['Prison Population Rate']],axis = 1, sort='True')

# %%
df
# Out:
#                                   Intentional Homicide Rate  \
# Afghanistan                                             NaN
# Albania                                            2.698926
# Algeria                                                 NaN
# American Samoa                                     5.397101
# American Samoa (USA)                                    NaN
# Andorra                                                 NaN
# Angola                                                  NaN
# Anguilla (United Kingdom)                               NaN
# Antigua and Barbuda                                     NaN
# Arab World                                              NaN
# Argentina                                          5.942564
# Armenia                                            2.978126
# Aruba                                                   NaN
# Aruba (Netherlands)                                     NaN
# Australia                                          0.941156
# ...
